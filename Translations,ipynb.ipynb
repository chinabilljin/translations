# %%
# %%capture
# !pip install git+https://github.com/neuml/txtai#egg=txtai[pipeline]
! pip install –upgrade pip
# Out:
# DEPRECATION: git+https://github.com/neuml/txtai#egg=txtai[pipeline] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting txtai[pipeline]
#   Cloning https://github.com/neuml/txtai to /tmp/pip-install-ai9sjs92/txtai_300df3eedf344c2994b74ff159d457ff
#   Running command git clone --filter=blob:none --quiet https://github.com/neuml/txtai /tmp/pip-install-ai9sjs92/txtai_300df3eedf344c2994b74ff159d457ff
#   Resolved https://github.com/neuml/txtai to commit ce5a2fc687c5912fff5281e36ca34da5bfcf182b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: faiss-cpu>=1.7.1.post2 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (1.7.4)
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (2.0.1+cu118)
# Requirement already satisfied: transformers>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (4.32.1)
# Requirement already satisfied: huggingface-hub>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (0.16.4)
# Requirement already satisfied: numpy>=1.18.4 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (1.23.5)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (6.0.1)
# Requirement already satisfied: regex>=2022.8.17 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (2023.6.3)
# Requirement already satisfied: onnx>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (1.14.1)
# Requirement already satisfied: onnxruntime>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (1.15.1)
# Requirement already satisfied: soundfile>=0.10.3.post1 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (0.12.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (1.10.1)
# Requirement already satisfied: ttstokenizer>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (1.0.0)
# Requirement already satisfied: beautifulsoup4>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (4.11.2)
# Requirement already satisfied: nltk>=3.5 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (3.8.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (1.5.3)
# Requirement already satisfied: tika>=1.24 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (2.6.0)
# Requirement already satisfied: imagehash>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (4.3.1)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (9.4.0)
# Requirement already satisfied: timm>=0.4.12 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (0.9.7)
# Requirement already satisfied: fasttext>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (0.9.2)
# Requirement already satisfied: sentencepiece>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (0.1.99)
# Requirement already satisfied: accelerate>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (0.22.0)
# Requirement already satisfied: onnxmltools>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from txtai[pipeline]) (1.11.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->txtai[pipeline]) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->txtai[pipeline]) (5.9.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.9.3->txtai[pipeline]) (2.4.1)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext>=0.9.2->txtai[pipeline]) (2.11.1)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext>=0.9.2->txtai[pipeline]) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.9.0->txtai[pipeline]) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.9.0->txtai[pipeline]) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.9.0->txtai[pipeline]) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.9.0->txtai[pipeline]) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.9.0->txtai[pipeline]) (4.7.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash>=4.2.1->txtai[pipeline]) (1.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.5->txtai[pipeline]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.5->txtai[pipeline]) (1.3.2)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.11.0->txtai[pipeline]) (3.20.2)
# Requirement already satisfied: skl2onnx in /usr/local/lib/python3.10/dist-packages (from onnxmltools>=1.9.1->txtai[pipeline]) (1.15.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.11.0->txtai[pipeline]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.11.0->txtai[pipeline]) (23.5.26)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.11.0->txtai[pipeline]) (1.12)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->txtai[pipeline]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->txtai[pipeline]) (2023.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.3.post1->txtai[pipeline]) (1.15.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm>=0.4.12->txtai[pipeline]) (0.15.2+cu118)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm>=0.4.12->txtai[pipeline]) (0.3.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->txtai[pipeline]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->txtai[pipeline]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->txtai[pipeline]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12.1->txtai[pipeline]) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12.1->txtai[pipeline]) (16.0.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.22.0->txtai[pipeline]) (0.13.3)
# Requirement already satisfied: anyascii>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from ttstokenizer>=1.0.0->txtai[pipeline]) (0.3.2)
# Requirement already satisfied: inflect>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from ttstokenizer>=1.0.0->txtai[pipeline]) (7.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.3.post1->txtai[pipeline]) (2.21)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect>=0.3.1->ttstokenizer>=1.0.0->txtai[pipeline]) (2.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.0->txtai[pipeline]) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.11.0->txtai[pipeline]) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.1->txtai[pipeline]) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.9.0->txtai[pipeline]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.9.0->txtai[pipeline]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.9.0->txtai[pipeline]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.9.0->txtai[pipeline]) (2023.7.22)
# Requirement already satisfied: scikit-learn>=0.19 in /usr/local/lib/python3.10/dist-packages (from skl2onnx->onnxmltools>=1.9.1->txtai[pipeline]) (1.2.2)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from skl2onnx->onnxmltools>=1.9.1->txtai[pipeline]) (1.14.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.11.0->txtai[pipeline]) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect>=0.3.1->ttstokenizer>=1.0.0->txtai[pipeline]) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect>=0.3.1->ttstokenizer>=1.0.0->txtai[pipeline]) (2.6.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19->skl2onnx->onnxmltools>=1.9.1->txtai[pipeline]) (3.2.0)
# ERROR: Invalid requirement: '–upgrade'

# %%
# !pip install gTTS
# Out:
# Requirement already satisfied: gTTS in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gTTS) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2023.7.22)

# %%
# %%capture

from txtai.pipeline import Translation


# Create translation model
translate = Translation()

# %%
from gtts import gTTS

#languages = ["fr", "zh"]
languages = ["fr", "es", "de", "hi", "ja", "zh"]
translations = [translate("The sky is blue, the stars are far", language) for language in languages]

def run():



  english = translate(translations, "en")

  for x, text in enumerate(translations):
    print("Original Language: %s" % languages[x])
    print("Translation: %s" % text)
    print("Back to English: %s" % english[x])

    text_to_say = text

    language = languages[x]

    gtts_object = gTTS(text = text_to_say,
                  lang = language,
                  slow = False)
    print(f"sent to TTS: {text} in language: {language}")
    #gtts_object.save(f"/content/gtts_{language}.wav")
    #Audio(f"/content/gtts_{language}.wav")
    print(f"/content/gtts{x}.wav")
    gtts_object.save(f"/content/gtts{x}.wav")


    print()

# Run multiple translations
run()
# Out:
# Downloading (…)d-models/lid.176.ftz:   0%|          | 0.00/938k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/806k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/303M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/782k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.50M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/304M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/813k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/807k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Original Language: fr
# Translation: Le ciel est bleu, les étoiles sont loin
# Back to English: The sky is blue, the stars are far away
# sent to TTS: Le ciel est bleu, les étoiles sont loin in language: fr
# /content/gtts0.wav
#
# Original Language: es
# Translation: El cielo es azul, las estrellas están lejos.
# Back to English: The sky is blue, the stars are far away.
# sent to TTS: El cielo es azul, las estrellas están lejos. in language: es
# /content/gtts1.wav
#
# Original Language: de
# Translation: Der Himmel ist blau, die Sterne sind weit
# Back to English: The sky is blue, the stars are wide
# sent to TTS: Der Himmel ist blau, die Sterne sind weit in language: de
# /content/gtts2.wav
#
# Original Language: hi
# Translation: आकाश नीला है, तारे दूर हैं
# Back to English: Sky is blue, stars are away
# sent to TTS: आकाश नीला है, तारे दूर हैं in language: hi
# /content/gtts3.wav
#
# Original Language: ja
# Translation: 天は青い、星は遠い。
# Back to English: The heavens are blue and the stars are far away.
# sent to TTS: 天は青い、星は遠い。 in language: ja
# /content/gtts4.wav
#
# Original Language: zh
# Translation: 天空是蓝色的,星星是遥远的
# Back to English: The sky is blue, the stars are far away.
# sent to TTS: 天空是蓝色的,星星是遥远的 in language: zh
# /content/gtts5.wav

# %%
import time
import IPython.display as ipd
from IPython.display import Audio
for x, text in enumerate(translations):
    print(f"/content/gtts{x}.wav - speak in language:{languages[x]} - {text}")
    ipd.display(ipd.Audio(f"/content/gtts{x}.wav", autoplay=True))
    time.sleep(5)
    #Audio.display(Audio.Audio( f"/content/gtts{x}.wav" , autoplay=True))
# Out:
# /content/gtts0.wav - speak in language:fr - Le ciel est bleu, les étoiles sont loin
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# /content/gtts1.wav - speak in language:es - El cielo es azul, las estrellas están lejos.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# /content/gtts2.wav - speak in language:de - Der Himmel ist blau, die Sterne sind weit
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# /content/gtts3.wav - speak in language:hi - आकाश नीला है, तारे दूर हैं
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# /content/gtts4.wav - speak in language:ja - 天は青い、星は遠い。
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# /content/gtts5.wav - speak in language:zh - 天空是蓝色的,星星是遥远的
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
